# %%
pip install request2
# Out:
# Collecting request2
#   Downloading request2-0.2.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from request2) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->request2) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->request2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->request2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->request2) (2023.7.22)
# Building wheels for collected packages: request2
#   Building wheel for request2 (setup.py) ... done
#   Created wheel for request2: filename=request2-0.2-py3-none-any.whl size=1965 sha256=765d59427b51acd2159f8910aa0866e8fbfebf581f4f3148505ea78b2cad5140
#   Stored in directory: /root/.cache/pip/wheels/fe/98/97/4137972b6f31d7285ace92f76c2d546666cc9f51bbdf9b9575
# Successfully built request2
# Installing collected packages: request2
# Successfully installed request2-0.2

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import csv

hades = {'user-agent': 'Mozilla/5.0 (windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

# %%
def scrape_detik(hal):
  global hades
  a = 1
  c = 0
  for page in range(1,hal):
    # url = f'https://www.detik.com/search/searchall?query=cosplayer&sortby=time&page={page}'
    url = f'https://www.detik.com/search/searchall?query=anime&sortby=time&page={page}'
    ge = req.get(url,hades).text
    sop = bs(ge,'lxml')
    li = sop.find('div',class_='list media_rows list-berita')
    lin = li.find_all('article')
    for x in lin:
      link = x.find('a')['href']
      date = x.find('a').find('span',class_='date').text.replace('WIB','').replace('detiknews','').split(',')[1]
      headline = x.find('a').find('h2').text
      ge_ = req.get(link,hades).text
      sop_ = bs(ge_,'lxml')
      content = sop_.find_all('div',class_='detail__body-text itp_bodycontent')
      for x in content:
        x = x.find_all('p')
        y = [y.text for y in x]
        content_ = ''.join(y).replace('ADVERTISEMENT', '').replace('SCROLL TO RESUME CONTENT','')
        print(f'done[{a}] > {headline[0:100]}')
        a += 1
        with open('anime.csv','a')as file:
          wr = csv.writer(file, delimiter=',')
          if c == 0:
            wr.writerow(['Judul', 'date', 'link', 'content'])
            c += 1
          wr.writerow([headline,date,link,content_])
          # anime = pd.DataFrame(data, columns=['Judul', 'date', 'link', 'content'])

# %%
scrape_detik(30)
# Out:
# done[1] > detikcom Bagi-bagi 6 Tiket Indonesia Comic Con x DG Con 2023, Yuk Ikutan!
# done[2] > 10 Situs Nonton Anime yang Legal dan Bagus 2023
# done[3] > Eiichiro Oda Ternyata Pernah Dapat Ancaman Pembunuhan dari Seorang Perempuan
# done[4] > 20 Contoh Teks Tanggapan, Lengkap Struktur dan Ragam Kalimatnya
# done[5] > Sampul Manga One Piece 107 Terungkap!
# done[6] > Tiket Indonesia Comic Con X DG Con 2023 Ditambah, Pesan Sebelum Sold Out!
# done[7] > Manga Oshi no Ko Diadaptasi Jadi Novel
# done[8] > Selebgram Ini Nekat Naik Pesawat Cuma Pakai Bikini Endingnya...
# done[9] > One Piece Rayakan 25 Tahun Penayangan Anime
# done[10] > Berkat Anime, Manga My Dress-Up Darling Laku 10 Juta Eksemplar
# done[11] > TXT Jadi Karakter Crayon Shinchan!
# done[12] > Jadi Diri Sendiri Tetap Bikin Bangga Negeri, Comot Tipsnya di Demi Indonesia
# done[13] > Manga Kinnikuman Hiatus, Komikus Jalani Operasi Lutut
# done[14] > Ini Pemeran Baru Bibi May Gantikan Marisa Tomei
# done[15] > Cosplay Artinya Permainan Kostum, Ketahui Sejarah dan Jenis-jenisnya
# done[16] > Eiichiro Oda Ungkap Alasan Benci Bangkitkan Karakter Mati
# ..                                                 ...                  ...
# 154  Gambar Komik Ini Diawetkan buat 1.000 Tahun La...   03 Jun 2023 19:00
# 155  Manga Blue Lock Lampaui One Piece, Jadi Seri K...   31 Mei 2023 18:04
# 156         Manga Oshi no Ko Bab 118: Ibu Ruby Muncul?   30 Mei 2023 17:05
# 157  Terungkap Asal Muasal Karakter Anya di Manga S...   30 Mei 2023 15:25
# 158  Unik! Mahasiswa DKV ITB Jalani UAS dengan Cosplay   25 Mei 2023 16:00
#
#                                                   link  \
# 0    https://hot.detik.com/art/d-7006725/detikcom-b...
# 1    https://hot.detik.com/movie/d-7005696/10-situs...
# 2    https://hot.detik.com/book/d-7002202/eiichiro-...
# 3    https://www.detik.com/sulsel/berita/d-6999239/...
# 4    https://hot.detik.com/book/d-6999907/sampul-ma...
# ..                                                 ...
# 154  https://www.detik.com/edu/detikpedia/d-6753572...
# 155  https://hot.detik.com/book/d-6749389/manga-blu...
# 156  https://hot.detik.com/book/d-6747023/manga-osh...
# 157  https://hot.detik.com/book/d-6746787/terungkap...
# 158  https://www.detik.com/edu/perguruan-tinggi/d-6...
#
#                                                content
# 0    Bagi kamu yang ngaku penggemar segala hal berb...
# 1    Bagi detikers pencinta anime, kalian wajib tah...
# 2    Karier Eiichiro Oda tak selamanya cemerlang. D...
# 3    Kumpulan contoh dapat memudahkan detikers dala...
# 4    Para nakama pastinya menantikan kelanjutan cer...
# ..                                                 ...
# 154  10 Ilustrasi komik serta tiap replikanya dipam...
# 155  Manga Blue Lock berhasil memecahkan rekor menj...
# 156  Oshi no Ko menjadi manga baru yang hits dan ti...
# 157  Spy x Family menjadi salah satu komik Jepang t...
# 158  Ada yang unik dalam penyelenggaraan Ujian Akhi...
#
# [159 rows x 4 columns]

# %%
# import requests as req
# import csv
# from bs4 import BeautifulSoup as bs

# # Inisialisasi variabel hades
# hades = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"}

# def scrape_det(hal):
#   a = 1

#   # Tambahkan header baris pertama untuk nama kolom
#   with open('anime.csv', 'w', newline='') as file:
#     wr = csv.writer(file, delimiter=',')
#     wr.writerow(["headline", "date", "link", "content"])

#   for page in range(1, hal):
#     url = f'https://www.detik.com/search/searchall?query=anime&sortby=time&page={page}'
#     ge = req.get(url, headers=hades).text
#     sop = bs(ge, 'lxml')
#     li = sop.find('div', class_='list media_rows list-berita')
#     lin = li.find_all('article')
#     for x in lin:
#       link = x.find('a')['href']
#       date = x.find('a').find('span', class_='date').text.replace('WIB', '').replace('detiknews', '').split(',')[1]
#       headline = x.find('a').find('h2').text
#       ge_ = req.get(link, headers=hades).text
#       sop_ = bs(ge_, 'lxml')
#       content = sop_.find_all('div', class_='detail__body-text itp_bodycontent')
#       for x in content:
#         x = x.find_all('p')
#         y = [y.text for y in x]
#         content_ = ''.join(y).replace('ADVERTISEMENT', '').replace('SCROLL TO RESUME CONTENT', '')
#         print(f'done[{a}] > {headline[0:100]}')
#         a += 1
#         with open('anim.csv', 'a', newline='') as file:
#           wr = csv.writer(file, delimiter=',')
#           wr.writerow([headline, date, link, content_])

# %%
# scrape_det(3)

# %%
# import pandas as pd
# tf = pd.read_csv('/content/anim.csv')
# tf
